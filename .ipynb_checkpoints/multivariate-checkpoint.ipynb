# %%
import pandas as pd
import numpy as np
import seaborn as sb

import matplotlib.pyplot as plt
from scipy.stats import norm

# %matplotlib inline

# %%
df = pd.read_csv('pokemon.csv')
df.shape
# Out:
# (800, 12)

# %%
df.rename(columns={'Type 1': 'type_1', 'Type 2': 'type_2', 'Sp. Atk': 'special_attack', 'Sp. Def': 'special_defense'}, inplace=True)
df.columns = map(str.lower, df.columns)
df.type_1.unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
cat_markers = [['Grass', 's'],
               ['Fire', '^'],
               ['Water', 'o'],
               ['Dragon', 'X']]


for cat, marker in cat_markers:
    df_cat = df[df['type_1'] == cat]
    plt.scatter(data = df_cat, x = 'attack', y = 'defense', marker = marker)
plt.legend(['Grass','Fire','Water','Dragon'], loc=2)
plt.show()

# %%
plt.scatter(data = df, x = 'attack', y = 'defense', s = 'hp')

# dummy series for adding legend
sizes = [50, 100, 150]
base_color = sb.color_palette()[0]
legend_obj = []
for s in sizes:
    legend_obj.append(plt.scatter([], [], s = s, color = base_color))
plt.legend(legend_obj, sizes)
plt.show()

# %%
df.hp.describe()
# Out:
# count    800.000000
# mean      69.258750
# std       25.534669
# min        1.000000
# 25%       50.000000
# 50%       65.000000
# 75%       80.000000
# max      255.000000
# Name: hp, dtype: float64

# %%
sb.palplot(sb.color_palette(n_colors=9))

# %%
sb.palplot(sb.color_palette('viridis', 9))

# %%
sb.palplot(sb.color_palette('vlag', 9))

# %%
g = sb.FacetGrid(data = df, hue = 'generation', height = 5,
                 palette = 'colorblind')
g.map(plt.scatter, 'attack', 'defense')
g.add_legend()

# %%
plt.scatter(data = df, x = 'attack', y = 'defense', c = 'attack')
plt.colorbar()
plt.show()

# %%
plt.scatter(data = df, x = 'attack', y = 'defense', c = 'hp',
            cmap = 'mako_r')
plt.colorbar()

# %%
type_cols = ['type_1','type_2']
non_type_cols = df.columns.difference(type_cols)
pkmn_types = df.melt(id_vars = non_type_cols, value_vars = type_cols, 
                          var_name = 'type_level', value_name = 'type').dropna()
pkmn_types.head()
# Out:
#    #  attack  defense  generation  hp  legendary           name  \
# 0  1      49       49           1  45      False      Bulbasaur
# 1  2      62       63           1  60      False        Ivysaur
# 2  3      82       83           1  80      False       Venusaur
# 3  4     100      123           1  80      False  Mega Venusaur
# 4  5      52       43           1  39      False     Charmander
#
#    special_attack  special_defense  speed type_level   type
# 0              65               65     45     type_1  Grass
# 1              80               80     60     type_1  Grass
# 2             100              100     80     type_1  Grass
# 3             122              120     80     type_1  Grass
# 4              60               50     65     type_1   Fire

# %%
g = sb.FacetGrid(data = df, col = 'legendary', height = 4)
g.map(sb.boxplot, 'generation', 'defense', order=[8,7,6,5,4,3,2,1])
plt.show()

# %%
g = sb.FacetGrid(data = df, col = 'legendary', row = 'generation', height = 2.5,
                margin_titles = True)
g.map(plt.scatter, 'attack', 'defense')
plt.show()

# %%
df.attack.describe()
# Out:
# count    800.000000
# mean      79.001250
# std       32.457366
# min        5.000000
# 25%       55.000000
# 50%       75.000000
# 75%      100.000000
# max      190.000000
# Name: attack, dtype: float64

# %%
ax = sb.barplot(data = df, x = 'generation', y = 'speed', hue = 'legendary')
ax.legend(loc = 8, ncol = 3, framealpha = 1, title = 'legendary')
plt.show()

# %%
ax = sb.pointplot(data = df, x = 'generation', y = 'speed', hue = 'legendary',
                  dodge = 0.3, linestyles = "")

# %%
def mean_poly(x, y, bins = 1, **kwargs):
    """ Custom adapted line plot code. """
    # set bin edges if none or int specified
    if type(bins) == int:
        bins = np.linspace(x.min(), x.max(), bins+1)
    bin_centers = (bin_edges[1:] + bin_edges[:-1]) / 2

    # compute counts
    data_bins = pd.cut(x, bins, right = False,
                       include_lowest = True)
    means = y.groupby(data_bins).mean()

    # create plot
    plt.errorbar(x = bin_centers, y = means, **kwargs)

bin_edges = np.arange(0, df['defense'].max()+1, 10)
g = sb.FacetGrid(data = df, hue = 'legendary', height = 5)
g.map(mean_poly, 'defense', 'attack', bins = bin_edges)
g.set_ylabels('mean(defense)')
g.add_legend()
plt.show()

# %%
df.columns
# Out:
# Index(['#', 'name', 'type_1', 'type_2', 'hp', 'attack', 'defense',
#        'special_attack', 'special_defense', 'speed', 'generation',
#        'legendary'],
#       dtype='object')

# %%
g = sb.PairGrid(data = df, vars = ['hp', 'attack', 'defense', 'special_attack', 'special_defense', 'speed'])
g.map_diag(plt.hist)
g.map_offdiag(plt.scatter)

# %%
g = sb.PairGrid(data = df, y_vars = ['hp', 'attack', 'defense'],
                x_vars = ['generation'])
g.map(sb.violinplot, inner = 'quartile')
plt.show()

# %%
sb.heatmap(df.corr(), annot = True, fmt = '.2f', cmap = 'vlag_r', center = 0)

# %%
df['atk'] = df.attack / df.special_attack
df['def'] = df.defense / df.special_defense

# %%
plt.scatter(data=df, x = 'atk', y = 'def', alpha = 0.3)
plt.xscale='log'
plt.yscale='log'
tick_loc=[0.25,0.5,1,2,4]
plt.xticks(tick_loc, tick_loc)
plt.yticks(tick_loc, tick_loc)
plt.xlim(-1, 5)
plt.ylim(-1, 5)
# Out:
# (-1, 5)
